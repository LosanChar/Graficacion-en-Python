# %% [markdown]
# <a href="https://colab.research.google.com/github/LosanChar/Graficacion-en-Python/blob/main/Lab1_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade --quiet gspread

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
def rgb2hex(r,g,b):
    return "#{:02x}{:02x}{:02x}".format(r,g,b)

# %%
import pandas as pd
wb = gc.open_by_url('https://docs.google.com/spreadsheets/d/1c77PROSuwJD-C2djwJ6hPwWqyYSnLPoeFgeDAC8Tgn4/edit#gid=0').sheet1

x1 = wb.col_values(3);
y1 = wb.col_values(4);
z1 = wb.col_values(5);

x2 = wb.col_values(6);
y2 = wb.col_values(7);
z2 = wb.col_values(8);

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

for i in range(1,24):
  ax.scatter(int(x1[i]), int(y1[i]), int(z1[i]), c= rgb2hex(int(x1[i]), int(y1[i]), int(z1[i])), marker='o', label='')
  ax.scatter(int(x2[i]), int(y2[i]), int(z2[i]), c= rgb2hex(int(x1[i]), int(y1[i]), int(z1[i])), marker='x', label='')

for i in range(1,24):
    ax.plot([int(x1[i]), int(x2[i])], [int(y1[i]), int(y2[i])], [int(z1[i]), int(z2[i])])

plt.title("3D Scatter Plot Example")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.
